# %%
# vertical bar plots with more customization.
#!PYTHONPATH=$(pwd)/:$PYTHONPATH 
# !python3 ./gen/run_gen_vbar_a0.py \
--wiki_path datasets/processed/deps/sanitized_wiki.json \
--stem_path datasets/processed/deps/mga_stem_kws.pickle \
--conf_path ./gen/conf/conf_vbar_a0.yaml \
--texture_dir datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# wiki bank size: 175543
# stem bank size: 96456
# # texture files: 1109
#   0%|▏                                        | 21/5000 [00:08<32:31,  2.55it/s]^C
# Traceback (most recent call last):
#   File "./gen/run_gen_vbar_a0.py", line 164, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_vbar_a0.py", line 141, in main
#     VerticalBarPlot(cfg, the_example, texture_files=texture_files).make_vertical_bar_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/vbar_plot_advanced.py", line 1084, in make_vertical_bar_plot
#     self.fig.savefig(save_path, format='jpg', bbox_inches='tight')
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3378, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2346, in print_figure
#     bbox_inches = self.figure.get_tightbbox(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 1776, in get_tightbbox
#     bbox = a.get_tightbbox(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 4385, in get_tightbbox
#     ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1415, in _get_tightbbox_for_layout_only
#     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1325, in get_tightbbox
#     self._update_label_position(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 2310, in _update_label_position
#     spinebbox = spine.get_window_extent()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/spines.py", line 158, in get_window_extent
#     drawn_ticks = self.axis._update_ticks()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1295, in _update_ticks
#     if mtransforms._interval_contains_close(interval_t, loc_t):
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/transforms.py", line 2932, in _interval_contains_close
#     a, b = interval
# KeyboardInterrupt

# %%
# 'Palatino Linotype',#Palatino

# %%
# horizontal bar plots.
# !python ./gen/run_gen_hbar.py \
--wiki_path ./datasets/processed/deps/sanitized_wiki.json \
--stem_path ./datasets/processed/deps/mga_stem_kws.pickle \
--conf_path ./gen/conf/conf_hbar.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# wiki bank size: 175543
# stem bank size: 96456
# # texture files: 1109
#   1%|▍                                        | 51/5000 [00:17<39:39,  2.08it/s]^C
# Traceback (most recent call last):
#   File "./gen/run_gen_hbar.py", line 166, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_hbar.py", line 143, in main
#     HorizontalBarPlot(cfg, the_example, texture_files=texture_files).make_horizontal_bar_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/hbar_plot_base.py", line 1036, in make_horizontal_bar_plot
#     self.fig.savefig(save_path, format='jpg', bbox_inches='tight')
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3378, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2346, in print_figure
#     bbox_inches = self.figure.get_tightbbox(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 1776, in get_tightbbox
#     bbox = a.get_tightbbox(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 4385, in get_tightbbox
#     ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1415, in _get_tightbbox_for_layout_only
#     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1323, in get_tightbbox
#     ticks_to_draw = self._update_ticks()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1270, in _update_ticks
#     minor_locs = self.get_minorticklocs()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1499, in get_minorticklocs
#     mask = np.isclose(tr_minor_locs[:, None], tr_major_locs[None, :],
#   File "<__array_function__ internals>", line 200, in isclose
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/numpy/core/numeric.py", line 2380, in isclose
#     return within_tol(x, y, atol, rtol)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/numpy/core/numeric.py", line 2360, in within_tol
#     with errstate(invalid='ignore'), _no_nep50_warning():
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/numpy/core/_ufunc_config.py", line 431, in __enter__
#     self.oldstate = seterr(**self.kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/numpy/core/_ufunc_config.py", line 122, in seterr
#     maskvalue = ((_errdict[divide] << SHIFT_DIVIDEBYZERO) +
# KeyboardInterrupt

# %%
# horizontal bar plot with more customization.
# !python ./gen/run_gen_hbar_a0.py \
--wiki_path ./datasets/processed/deps/sanitized_wiki.json \
--stem_path ./datasets/processed/deps/mga_stem_kws.pickle \
--conf_path ./gen/conf/conf_hbar_a0.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# wiki bank size: 175543
# stem bank size: 96456
# # texture files: 1109
#   1%|▏                                        | 28/5000 [00:08<28:12,  2.94it/s]^C
# Traceback (most recent call last):
#   File "./gen/run_gen_hbar_a0.py", line 166, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_hbar_a0.py", line 143, in main
#     HorizontalBarPlot(cfg, the_example, texture_files=texture_files).make_horizontal_bar_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/hbar_plot_advanced.py", line 1043, in make_horizontal_bar_plot
#     self.fig.savefig(buf, format='png', bbox_inches='tight')
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3378, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2342, in print_figure
#     self.figure.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 95, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3175, in draw
#     mimage._draw_list_compositing_images(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 3028, in draw
#     self._update_title_position(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 2972, in _update_title_position
#     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1325, in get_tightbbox
#     self._update_label_position(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 2565, in _update_label_position
#     bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 2100, in _get_tick_boxes_siblings
#     tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1304, in _get_ticklabel_bboxes
#     return ([tick.label1.get_window_extent(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1304, in <listcomp>
#     return ([tick.label1.get_window_extent(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 959, in get_window_extent
#     bbox, info, descent = self._get_layout(self._renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 450, in _get_layout
#     ymax = corners_rotated[:, 1].max()
# KeyboardInterrupt

# %%
# dot plots.
# !python ./gen/run_gen_dot.py \
--stem_path ./datasets/processed/deps/mga_stem_kws.pickle \
--conf_path ./gen/conf/conf_dot.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# stem bank size: 96456
# # texture files: 1109
#   1%|▎                                        | 33/5000 [00:08<21:27,  3.86it/s]^C
# Traceback (most recent call last):
#   File "./gen/run_gen_dot.py", line 163, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_dot.py", line 141, in main
#     BasicDotPlot(cfg, the_example, texture_files=texture_files).make_dot_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/dot_plot_base.py", line 305, in __init__
#     self.fig, self.ax = self.get_figure_handles()
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/dot_plot_base.py", line 341, in get_figure_handles
#     fig, ax = plt.subplots(figsize=(width, height), dpi=dpi)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/pyplot.py", line 1502, in subplots
#     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 917, in subplots
#     axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/gridspec.py", line 299, in subplots
#     axarr[row, col] = figure.add_subplot(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 768, in add_subplot
#     ax = projection_class(self, *args, **pkw)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 683, in __init__
#     self.clear()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 1395, in clear
#     self.__clear()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 1312, in __clear
#     self.grid(False)  # Disable grid on init to use rcParameter
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 3196, in grid
#     self.yaxis.grid(visible, which=which, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1660, in grid
#     self.set_tick_params(which='major', **gridkw)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 947, in set_tick_params
#     for tick in self.majorTicks:
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 595, in __get__
#     instance.majorTicks.append(tick)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 594, in __get__
#     tick = instance._get_tick(major=True)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1551, in _get_tick
#     return self._tick_class(self.axes, 0, major=major, **tick_kw)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 489, in __init__
#     self.label1.set(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 147, in <lambda>
#     cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1231, in set
#     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1223, in _internal_update
#     return self._update_props(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1199, in _update_props
#     ret.append(func(v))
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 1010, in set_horizontalalignment
#     _api.check_in_list(['center', 'right', 'left'], align=align)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/_api/__init__.py", line 126, in check_in_list
#     for key, val in kwargs.items():
# KeyboardInterrupt

# %%
# line plots.
# !python ./gen/run_gen_line.py \
--wiki_path ./datasets/processed/deps/sanitized_wiki.json \
--stem_path ./datasets/processed/deps/mga_stem_kws.pickle \
--conf_path ./gen/conf/conf_line.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# wiki bank size: 175543
# stem bank size: 96456
# # texture files: 1109
#   1%|▎                                        | 31/5000 [00:12<37:01,  2.24it/s]^C
# Traceback (most recent call last):
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/contextlib.py", line 120, in __exit__
#     next(self.gen)
# StopIteration
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "./gen/run_gen_line.py", line 178, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_line.py", line 155, in main
#     BasicLinePlot(cfg, the_example, texture_files=texture_files).make_line_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/line_plot_base.py", line 1724, in make_line_plot
#     self.fig.tight_layout()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3544, in tight_layout
#     engine.execute(self)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/layout_engine.py", line 184, in execute
#     kwargs = get_tight_layout_figure(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/_tight_layout.py", line 266, in get_tight_layout_figure
#     kwargs = _auto_adjust_subplotpars(fig, renderer,
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/_tight_layout.py", line 82, in _auto_adjust_subplotpars
#     bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1415, in _get_tightbbox_for_layout_only
#     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 4385, in get_tightbbox
#     ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1415, in _get_tightbbox_for_layout_only
#     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1323, in get_tightbbox
#     ticks_to_draw = self._update_ticks()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1272, in _update_ticks
#     minor_ticks = self.get_minor_ticks(len(minor_locs))
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1615, in get_minor_ticks
#     tick = self._get_tick(major=False)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1551, in _get_tick
#     return self._tick_class(self.axes, 0, major=major, **tick_kw)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 417, in __init__
#     super().__init__(*args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 178, in __init__
#     self.label2 = mtext.Text(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/_api/deprecation.py", line 454, in wrapper
#     return func(*args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 183, in __init__
#     self.update(kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 231, in update
#     super().update(kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1213, in update
#     return self._update_props(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1199, in _update_props
#     ret.append(func(v))
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/contextlib.py", line 121, in __exit__
#     except StopIteration:
# KeyboardInterrupt

# %%
# line plots with more customization.
# !python ./gen/run_gen_line_a0.py \
--wiki_path ./datasets/processed/deps/sanitized_wiki.json \
--stem_path ./datasets/processed/deps/mga_stem_kws.pickle \
--conf_path ./gen/conf/conf_line_a0.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# wiki bank size: 175543
# stem bank size: 96456
# # texture files: 1109
#   1%|▏                                        | 26/5000 [00:14<45:14,  1.83it/s]^C
# Traceback (most recent call last):
#   File "./gen/run_gen_line_a0.py", line 216, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_line_a0.py", line 193, in main
#     BasicLinePlot(cfg, the_example, texture_files=texture_files).make_line_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/line_plot_advanced.py", line 1703, in make_line_plot
#     self.fig.tight_layout()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3544, in tight_layout
#     engine.execute(self)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/layout_engine.py", line 184, in execute
#     kwargs = get_tight_layout_figure(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/_tight_layout.py", line 266, in get_tight_layout_figure
#     kwargs = _auto_adjust_subplotpars(fig, renderer,
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/_tight_layout.py", line 82, in _auto_adjust_subplotpars
#     bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1415, in _get_tightbbox_for_layout_only
#     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 4385, in get_tightbbox
#     ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1415, in _get_tightbbox_for_layout_only
#     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1323, in get_tightbbox
#     ticks_to_draw = self._update_ticks()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1272, in _update_ticks
#     minor_ticks = self.get_minor_ticks(len(minor_locs))
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1615, in get_minor_ticks
#     tick = self._get_tick(major=False)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1551, in _get_tick
#     return self._tick_class(self.axes, 0, major=major, **tick_kw)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 417, in __init__
#     super().__init__(*args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 174, in __init__
#     self.label1 = mtext.Text(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/_api/deprecation.py", line 454, in wrapper
#     return func(*args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 183, in __init__
#     self.update(kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 231, in update
#     super().update(kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1213, in update
#     return self._update_props(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1188, in _update_props
#     with cbook._setattr_cm(self, eventson=False):
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/cbook/__init__.py", line 2008, in _setattr_cm
#     if attr in obj.__dict__ or orig is sentinel:
# KeyboardInterrupt

# %%
# line plots with shared origin edge case.
# !python ./gen/run_gen_line_shared.py \
--conf_path ./gen/conf/conf_line_shared.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# # texture files: 1109
#   1%|▏                                        | 28/5000 [00:05<17:18,  4.79it/s]^C
# Traceback (most recent call last):
#   File "./gen/run_gen_line_shared.py", line 165, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_line_shared.py", line 144, in main
#     SharedLinePlot(cfg, the_example, texture_files=texture_files).make_line_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/line_plot_shared.py", line 1732, in make_line_plot
#     self.fig.savefig(save_path, format='jpg', bbox_inches='tight')
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3378, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2342, in print_figure
#     self.figure.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 95, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3175, in draw
#     mimage._draw_list_compositing_images(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 3064, in draw
#     mimage._draw_list_compositing_images(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1376, in draw
#     ticks_to_draw = self._update_ticks()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1272, in _update_ticks
#     minor_ticks = self.get_minor_ticks(len(minor_locs))
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1615, in get_minor_ticks
#     tick = self._get_tick(major=False)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1551, in _get_tick
#     return self._tick_class(self.axes, 0, major=major, **tick_kw)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 417, in __init__
#     super().__init__(*args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 174, in __init__
#     self.label1 = mtext.Text(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/_api/deprecation.py", line 454, in wrapper
#     return func(*args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 183, in __init__
#     self.update(kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/text.py", line 231, in update
#     super().update(kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1213, in update
#     return self._update_props(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1199, in _update_props
#     ret.append(func(v))
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 1057, in set_visible
#     self.pchanged()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 428, in pchanged
#     self._callbacks.process("pchanged")
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/cbook/__init__.py", line 296, in process
#     def process(self, s, *args, **kwargs):
# KeyboardInterrupt
#   1%|▏                                        | 29/5000 [00:06<17:37,  4.70it/s]

# %%
# line plots with even more diverse styles.
# !python ./gen/run_gen_line_a3.py \
--wiki_path ./datasets/processed/deps/sanitized_wiki.json \
--stem_path ./datasets/processed/deps/mga_stem_kws.pickle \
--conf_path ./gen/conf/conf_line_a3.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# wiki bank size: 175543
# stem bank size: 96456
# # texture files: 0
#   0%|▏                                        | 30/7500 [00:06<33:06,  3.76it/s]^C

# %%
# scatter plots.
# !python ./gen/run_gen_scatter.py \
--conf_path ./gen/conf/conf_scatter.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# # texture files: 1109
#   1%|▎                                        | 33/5000 [00:16<45:16,  1.83it/s]^C
# Traceback (most recent call last):
#   File "./gen/run_gen_scatter.py", line 126, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_scatter.py", line 105, in main
#     BasicScatterPlot(cfg, the_example, texture_files=texture_files).make_scatter_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/scatter_plot_base.py", line 1008, in make_scatter_plot
#     self.fig.savefig(save_path, format='jpg', bbox_inches='tight')
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3378, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2342, in print_figure
#     self.figure.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 95, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3175, in draw
#     mimage._draw_list_compositing_images(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 3064, in draw
#     mimage._draw_list_compositing_images(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/collections.py", line 972, in draw
#     super().draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/collections.py", line 388, in draw
#     extents = paths[0].get_extents(combined_transform)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/path.py", line 635, in get_extents
#     _, dzeros = curve.axis_aligned_extrema()
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/bezier.py", line 295, in axis_aligned_extrema
#     dCj = np.arange(1, n+1)[:, None] * Cj[1:]
# KeyboardInterrupt
#   1%|▎                                        | 33/5000 [00:17<43:05,  1.92it/s]

# %%
# scatter plots with more customization.
# !python ./gen/run_gen_scatter_a0.py \
--conf_path ./gen/conf/conf_scatter_a0.yaml \
--texture_dir ./datasets/processed/deps/mga_textures_cc/mga_textures_cc
# Out:
# # texture files: 1109
#   1%|▌                                        | 73/5000 [00:15<14:42,  5.58it/s]^C
# Traceback (most recent call last):
#   File "./gen/run_gen_scatter_a0.py", line 123, in <module>
#     main(args, cfg)
#   File "./gen/run_gen_scatter_a0.py", line 102, in main
#     BasicScatterPlot(cfg, the_example, texture_files=texture_files).make_scatter_plot(image_id)
#   File "/media/na/e0adac50-20ce-4eb4-9c9d-98faf82ddd46/gen/src/scatter_plot_advanced.py", line 1096, in make_scatter_plot
#     self.fig.savefig(save_path, format='jpg', bbox_inches='tight')
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3378, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2366, in print_figure
#     result = print_method(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backend_bases.py", line 2232, in <lambda>
#     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 526, in print_jpg
#     self._print_pil(filename_or_obj, "jpeg", pil_kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 457, in _print_pil
#     FigureCanvasAgg.draw(self)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py", line 400, in draw
#     self.figure.draw(self.renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 95, in draw_wrapper
#     result = draw(artist, renderer, *args, **kwargs)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/figure.py", line 3175, in draw
#     mimage._draw_list_compositing_images(
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/artist.py", line 72, in draw_wrapper
#     return draw(artist, renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 3028, in draw
#     self._update_title_position(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 2963, in _update_title_position
#     bb = ax.xaxis.get_tightbbox(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 1325, in get_tightbbox
#     self._update_label_position(renderer)
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/axis.py", line 2314, in _update_label_position
#     bbox = mtransforms.Bbox.union(bboxes + [spinebbox])
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/matplotlib/transforms.py", line 656, in union
#     y0 = np.min([bbox.ymin for bbox in bboxes])
#   File "<__array_function__ internals>", line 200, in amin
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 2946, in amin
#     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#   File "/home/na/miniconda3/envs/base_4/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 69, in _wrapreduction
#     def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# KeyboardInterrupt
#   1%|▌                                        | 73/5000 [00:16<18:07,  4.53it/s]
